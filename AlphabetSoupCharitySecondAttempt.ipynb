# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()

pd.set_option('display.max_columns', None)
import numpy as np

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold

# Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve, RocCurveDisplay

# Pre-Processing
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# Tensorflow
import tensorflow as tf

# %%
df = application_df

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
df = df.drop(columns=['EIN', 'NAME'])

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
unique_values = df.nunique()
print(unique_values)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
df.columns
# Out:
# Index(['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
#        'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS',
#        'ASK_AMT', 'IS_SUCCESSFUL'],
#       dtype='object')

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
#  YOUR CODE GOES HERE
application_type_counts = df['APPLICATION_TYPE'].value_counts()
print(application_type_counts)

types_to_replace = application_type_counts[application_type_counts < 200].index
# df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(types_to_replace, 'Other')
df['AFFILIATION_TYPE'] = df['APPLICATION_TYPE'].replace(types_to_replace, 'Other')
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
cutoff_value = 200
application_types_to_replace = application_df['APPLICATION_TYPE'].value_counts()[application_df['APPLICATION_TYPE'].value_counts() < cutoff_value].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
#  YOUR CODE GOES HERE
# Choose a cutoff value
cutoff_value = 200

# Look at CLASSIFICATION value counts
classification_counts = application_df['CLASSIFICATION'].value_counts()

# Create a list of classifications that occur less than the cutoff value
classifications_to_replace = classification_counts[classification_counts < cutoff_value].index.tolist()

# Replace in dataframe
for classification in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(classification, "Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1197
# C7000      777
# C1700      287
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
cutoff_value = 200
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1197
# C7000      777
# C1700      287
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
# Create dummy variables for the specified categorical columns
application_dummies = pd.get_dummies(application_df[['APPLICATION_TYPE', 'CLASSIFICATION']], drop_first=True)

# Concatenate the dummy variables with the original DataFrame
application_df = pd.concat([application_df, application_dummies], axis=1)

# Optionally, drop the original categorical columns if they are no longer needed
application_df.drop(['APPLICATION_TYPE', 'CLASSIFICATION'], axis=1, inplace=True)

# Check the updated DataFrame
application_df.head()
# Out:
#         EIN                                      NAME       AFFILIATION  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB       Independent
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR       Independent
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  CompanySponsored
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  CompanySponsored
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT       Independent
#
#        USE_CASE  ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  \
# 0    ProductDev   Association       1              0                      N
# 1  Preservation  Co-operative       1         1-9999                      N
# 2    ProductDev   Association       1              0                      N
# 3  Preservation         Trust       1    10000-24999                      N
# 4     Heathcare         Trust       1  100000-499999                      N
#
#    ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  \
# 0     5000              1                  True                 False
# 1   108590              1                 False                 False
# 2     5000              0                 False                 False
# 3     6692              1                 False                 False
# 4   142590              1                 False                 False
#
#    APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# 0                False                False                False
# 1                 True                False                False
# 2                False                False                 True
# 3                 True                False                False
# 4                 True                False                False
#
#    APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    CLASSIFICATION_C1200  CLASSIFICATION_C1700  CLASSIFICATION_C2000  \
# 0                 False                 False                 False
# 1                 False                 False                  True
# 2                 False                 False                 False
# 3                 False                 False                  True
# 4                 False                 False                 False
#
#    CLASSIFICATION_C2100  CLASSIFICATION_C3000  CLASSIFICATION_C7000  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                  True                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    CLASSIFICATION_Other
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False

# %%
application_df.columns
# Out:
# Index(['EIN', 'NAME', 'AFFILIATION', 'USE_CASE', 'ORGANIZATION', 'STATUS',
#        'INCOME_AMT', 'SPECIAL_CONSIDERATIONS', 'ASK_AMT', 'IS_SUCCESSFUL',
#        'APPLICATION_TYPE_T10', 'APPLICATION_TYPE_T19', 'APPLICATION_TYPE_T3',
#        'APPLICATION_TYPE_T4', 'APPLICATION_TYPE_T5', 'APPLICATION_TYPE_T6',
#        'APPLICATION_TYPE_T7', 'APPLICATION_TYPE_T8', 'CLASSIFICATION_C1200',
#        'CLASSIFICATION_C1700', 'CLASSIFICATION_C2000', 'CLASSIFICATION_C2100',
#        'CLASSIFICATION_C3000', 'CLASSIFICATION_C7000', 'CLASSIFICATION_Other'],
#       dtype='object')

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE

# Split our preprocessed data into our features and target arrays
X = application_df.drop('IS_SUCCESSFUL', axis=1)  # Features
y = application_df['IS_SUCCESSFUL']  # Target

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, test_size=0.2)  # Adjust test_size as needed

# Check the shapes of the resulting datasets
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
print(X_train)
# Out:
# (27439, 24) (6860, 24) (27439,) (6860,)
#              EIN                                               NAME  \
# 33580  946102210                                    AMERICAN LEGION
# 21025  562559152  EXPERIMENTAL AIRCRAFT ASSOCIATION ROCKY MOUNTA...
# 20933  562444266                     FOURTH DISTRICT DENTAL SOCIETY
# 10861  364687225                 COUNTRY DANCE AND SONG SOCIETY INC
# 28821  813585813                                 TEMPLE LIFE CENTER
# ...          ...                                                ...
# 20558  510649064                                       SONGEAS KIDS
# 18547  473147918                   TOGETHER WE CAN CHANGE THE WORLD
# 3476   237112123                      AMERICAN POSTAL WORKERS UNION
# 22633  621624993  NATIONAL SOCIETY OF THE DAUGHTERS OF THE AMERI...
# 16854  465014769        REGIONAL FOOD BANK OF NORTHEAST FLORIDA INC
#
#             AFFILIATION      USE_CASE ORGANIZATION  STATUS     INCOME_AMT  \
# 33580  CompanySponsored  Preservation  Association       1              0
# 21025       Independent  Preservation        Trust       1              0
# 20933       Independent    ProductDev        Trust       1  100000-499999
# 10861  CompanySponsored  Preservation        Trust       1  100000-499999
# 28821       Independent  Preservation        Trust       1              0
# ...                 ...           ...          ...     ...            ...
# 20558       Independent  Preservation        Trust       1  100000-499999
# 18547       Independent  Preservation        Trust       1  100000-499999
# 3476   CompanySponsored    ProductDev  Association       1    25000-99999
# 22633  CompanySponsored  Preservation  Association       1              0
# 16854       Independent  Preservation        Trust       1        10M-50M
#
#       SPECIAL_CONSIDERATIONS  ASK_AMT  APPLICATION_TYPE_T10  \
# 33580                      N     5000                 False
# 21025                      N     5000                 False
# 20933                      N    73627                 False
# 10861                      N    75188                 False
# 28821                      N     5000                 False
# ...                      ...      ...                   ...
# 20558                      N    51827                 False
# 18547                      N    55178                 False
# 3476                       N   103405                 False
# 22633                      N     5000                 False
# 16854                      N  1869240                 False
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 33580                  True                False                False
# 21025                 False                 True                False
# 20933                 False                False                False
# 10861                 False                 True                False
# 28821                 False                 True                False
# ...                     ...                  ...                  ...
# 20558                 False                 True                False
# 18547                 False                 True                False
# 3476                  False                False                False
# 22633                 False                 True                False
# 16854                 False                 True                False
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  \
# 33580                False                False                False
# 21025                False                False                False
# 20933                False                 True                False
# 10861                False                False                False
# 28821                False                False                False
# ...                    ...                  ...                  ...
# 20558                False                False                False
# 18547                False                False                False
# 3476                  True                False                False
# 22633                False                False                False
# 16854                False                False                False
#
#        APPLICATION_TYPE_T8  CLASSIFICATION_C1200  CLASSIFICATION_C1700  \
# 33580                False                 False                 False
# 21025                False                 False                 False
# 20933                False                 False                 False
# 10861                False                 False                 False
# 28821                False                  True                 False
# ...                    ...                   ...                   ...
# 20558                False                 False                 False
# 18547                False                 False                 False
# 3476                 False                 False                 False
# 22633                False                  True                 False
# 16854                False                 False                 False
#
#        CLASSIFICATION_C2000  CLASSIFICATION_C2100  CLASSIFICATION_C3000  \
# 33580                 False                 False                 False
# 21025                 False                  True                 False
# 20933                  True                 False                 False
# 10861                 False                 False                 False
# 28821                 False                 False                 False
# ...                     ...                   ...                   ...
# 20558                 False                 False                 False
# 18547                 False                 False                 False
# 3476                  False                 False                  True
# 22633                 False                 False                 False
# 16854                 False                 False                 False
#
#        CLASSIFICATION_C7000  CLASSIFICATION_Other
# 33580                 False                 False
# 21025                 False                 False
# 20933                 False                 False
# 10861                 False                 False
# 28821                 False                 False
# ...                     ...                   ...
# 20558                 False                 False
# 18547                 False                 False
# 3476                  False                 False
# 22633                 False                 False
# 16854                 False                 False
#
# [27439 rows x 24 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_df.drop('IS_SUCCESSFUL', axis=1)  # Features
y = application_df['IS_SUCCESSFUL']  # Target

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, test_size=0.2)  # Adjust test_size as needed

# Check if any columns are of type 'object'
object_columns = X_train.select_dtypes(include=['object']).columns

# If there are object columns, drop them before scaling
if len(object_columns) > 0:
    X_train = X_train.drop(object_columns, axis=1)
    X_test = X_test.drop(object_columns, axis=1)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Check the shapes of the resulting datasets
print(X_train_scaled.shape, X_test_scaled.shape, y_train.shape, y_test.shape)
print(X_train_scaled)
# Out:
# (27439, 18) (6860, 18) (27439,) (6860,)
# [[ 1.73900538  0.01350021 -0.03369006 ... -0.2430079  -0.15078657
#   -0.18906782]
#  [ 0.17439341  0.01350021 -0.03369006 ... -0.2430079  -0.15078657
#   -0.18906782]
#  [ 0.17392475  0.01350021 -0.03283533 ... -0.2430079  -0.15078657
#   -0.18906782]
#  ...
#  [-1.15322367  0.01350021 -0.03246445 ...  4.11509258 -0.15078657
#   -0.18906782]
#  [ 0.41534451  0.01350021 -0.03369006 ... -0.2430079  -0.15078657
#   -0.18906782]
#  [-0.22352569  0.01350021 -0.01047127 ... -0.2430079  -0.15078657
#   -0.18906782]]

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 10

# Create the Keras Sequential model
nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))
# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))
# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
# Check the structure of the model
nn.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 80)                  │           1,520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 30)                  │           2,430 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              31 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,981 (15.55 KB)
#  Trainable params: 3,981 (15.55 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.6016 - loss: 0.6540
# Epoch 2/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6129 - loss: 0.6437
# Epoch 3/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6179 - loss: 0.6390
# Epoch 4/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6211 - loss: 0.6356
# Epoch 5/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6148 - loss: 0.6389
# Epoch 6/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6180 - loss: 0.6387
# Epoch 7/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6198 - loss: 0.6379
# Epoch 8/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6215 - loss: 0.6353
# Epoch 9/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6176 - loss: 0.6352
# Epoch 10/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6250 - loss: 0.6326
# Epoch 11/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6277 - loss: 0.6291
# Epoch 12/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6319 - loss: 0.6296
# Epoch 13/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6280 - loss: 0.6308
# Epoch 14/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6302 - loss: 0.6288
# Epoch 15/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6255 - loss: 0.6276
# Epoch 16/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6278 - loss: 0.6317
# Epoch 17/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6316 - loss: 0.6298
# Epoch 18/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6269 - loss: 0.6346
# Epoch 19/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6256 - loss: 0.6327
# Epoch 20/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6296 - loss: 0.6317
# Epoch 21/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6338 - loss: 0.6278
# Epoch 22/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6357 - loss: 0.6291
# Epoch 23/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6279 - loss: 0.6302
# Epoch 24/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6346 - loss: 0.6245
# Epoch 25/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6263 - loss: 0.6299
# Epoch 26/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6327 - loss: 0.6263
# Epoch 27/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6382 - loss: 0.6246
# Epoch 28/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6371 - loss: 0.6254
# Epoch 29/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6317 - loss: 0.6278
# Epoch 30/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6368 - loss: 0.6276
# Epoch 31/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6288 - loss: 0.6317
# Epoch 32/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6340 - loss: 0.6252
# Epoch 33/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6307 - loss: 0.6284
# Epoch 34/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6346 - loss: 0.6288
# Epoch 35/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6400 - loss: 0.6235
# Epoch 36/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6322 - loss: 0.6249
# Epoch 37/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6372 - loss: 0.6240
# Epoch 38/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6309 - loss: 0.6269
# Epoch 39/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6326 - loss: 0.6271
# Epoch 40/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6315 - loss: 0.6257
# Epoch 41/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6316 - loss: 0.6275
# Epoch 42/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.